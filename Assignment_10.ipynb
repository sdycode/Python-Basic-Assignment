# %% [markdown]
# <a href="https://colab.research.google.com/github/sdycode/Python-Basic-Assignment/blob/main/Assignment_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. How do you distinguish between shutil.copy() and shutil.copytree()?
# -->  shutil.copy() will copy a single file, shutil.copytree() will copy an entire folder and every folder and file contained in it.
#
# 2. What function is used to rename files?
# --> os.rename(source, dest) used to rename files
#
# 3. What is the difference between the delete functions in the send2trash and shutil modules?
# --> The send2trash functions will move a file or folder to the recycle bin, while shutil functions will permanently delete files and folders.
#
# 4. ZipFile objects have a close() method just like File objects’ close() method. What ZipFile method is equivalent to File objects’ open() method?
# -->  zipfile.ZipFile(path for zipfile) is the euivalent function of open() method.
# And zipfile.extractall() is method to extract content of zip file
#
# 5. Create a programme that searches a folder tree for files with a certain file extension (such as .pdf or .jpg). Copy these files from whatever location they are in to a new folder.
# -->
# import os, shutil
#
# def moveFileType(folder):
#     print('folder is', folder)
#     for folderName, subfolders, filenames in os.walk(folder):
#
#         for subfolder in subfolders:
#             for filename in filenames:
#                 # print(filename)
#                 if filename.endswith('.jpg'):
#                     print(filename," ---- with jpg")
#                     shutil.copy(folder+'\\'+filename, 'H:\\Shubham_Codes\\Shubham_Codes\\Python\\Python Notes')
#
# moveFileType('H:\\Shubham_Codes\\Shubham_Codes\\Python\\')
