# %% [markdown]
# <a href="https://colab.research.google.com/github/sdycode/Python-Basic-Assignment/blob/main/Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.What are the two values of the Boolean data type? How do you write them?

# %% [markdown]
# → Two values of Boolean type TRUE and FALSE
# 	print(bool(0))
# 	print(bool(none))
# 	print(bool(false))

# %% [markdown]
# 2. What are the three different types of Boolean operators?

# %% [markdown]
# -->
# and  : return true if both are true
# or  : return true if anyone is true
# not  : invert the operation or can be used to check equality
# # New Section

# %% [markdown]
# 3. Make a list of each Boolean operator's truth tables (i.e. every possible combination of Boolean values for the operator and what it evaluate ).

# %% [markdown]
# -->
#
# TRUE
# TRUE
# TRUE
#
# TRUE
# FALSE
# FALSE
#
#
# FALSE
# TRUE
# FALSE
#
# FALSE
# FALSE
# FALSE
#
# OR operator
#
# TRUE
# TRUE
# TRUE
#
# TRUE
# FALSE
# TRUE
#
# FALSE
# TRUE
# TRUE
#
# FALSE
# FALSE
# FALSE
#
#
# Not operator
#
#
# not(true)
# false
#
# not(false)
# true

# %% [markdown]
# 4. What are the values of the following expressions?

# %% [markdown]
# # -->
# (5 > 4) and (3 == 5)	→ False
# not (5 > 4)	→ False
# (5 > 4) or (3 == 5) 	→True
# not ((5 > 4) or (3 == 5))		→ false
# (True and True) and (True == False)	→ False
# (not False) or (not True)	→ True

# %% [markdown]
# 5. What are the six comparison operators?

# %% [markdown]
# -->
# Less than ( < )
# Less than or equal to ( <= )
# Greater than ( > )
# Greater than or equal to ( >= )
# Equal to ( == )
# Not equal to ( != )

# %% [markdown]
# 6. How do you tell the difference between the equal to and assignment operators?Describe a condition and when you would use one.

# %% [markdown]
# -→
# Assignment operator (=) is used to give or assign a specific value to variable.
# Whereas Equal to (==) operator is used to check equality between two different variables
# E.g.	x=10
# 	y=6
# 	z=x #here z is assigned value of x (10)
# 	T = (y==x) # so here T is false as y is not equal to x

# %% [markdown]
# 7. Identify the three blocks in this code:
# spam = 0
# if spam == 10:
# print('eggs')
# if spam > 5:
# print('bacon')
# Else:
# print('ham')
# print('spam')
# print('spam')

# %% [markdown]
# -->
#
# Block 1
#
# {
#   spam = 0
# }
#
#
# Block 2
#
# {
#  if spam == 10:
# print('eggs')
# }
#
# Block 3
#
# {
#   if spam > 5:
# print('bacon')
# Else:
# print('ham')
# print('spam')
# print('spam')
#
# }

# %% [markdown]
# 8. Write code that prints Hello if 1 is stored in spam, prints Howdy if 2 is stored in spam, and prints Greetings! if anything else is stored in spam.

# %%
spam =1
if spam == 1:
  print('Hello')
elif spam==2:
	print('Howdy')
else :
	print('Greetings!')
# Out:
# Hello
