# %% [markdown]
# <a href="https://colab.research.google.com/github/sdycode/Python-Basic-Assignment/blob/main/Assignment_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. In what modes should the PdfFileReader() and PdfFileWriter() File objects will be opened?
# -->  PdfFileReader() and PdfFileWriter() File objects will be opened in 'rb' i.e read binary mode.
#
# 2. From a PdfFileReader object, how do you get a Page object for page 5?
# --> From PdfFileReader object, we can call
# pageObj = PdfFileReader.getPage(5),
# then we will get page object for page 5
#
# 3. What PdfFileReader variable stores the number of pages in the PDF document?
# --> PdfFileReader.numPages give the no of pages present in PDF document.
#
# 4. If a PdfFileReader object’s PDF is encrypted with the password swordfish, what must you do before you can obtain Page objects from it?
# --> We can run following commands to decrypt PDF.
# file = PdfFileReader("encrypted_file.pdf")
#
# if file.isEncrypted:
#     file.decrypt("password")
#      for pageNo in range(file.numPages):
#         pageObject = file.getPage(pageNo)
#
# 5. What methods do you use to rotate a page?
# -->  page = pdfReader.getPage(0)
#  page.rotateClockwise(90) & page.rotateCounterClockwise(90) can be used to rotate pages.
#
# 6. What is the difference between a Run object and a Paragraph object?
# -->
# Run object :A run is the object most closely associated with inline content; text, pictures, and other items that are flowed between the block-item boundaries within a paragraph.
# Paragraph object : Paragraph object is collection of many runs object where individual attributes are present.
#
# 7. How do you obtain a list of Paragraph objects for a Document object that’s stored in a variable named doc?
# --> doc.paragraphs will give list of paragraphs available in document
#
#
# 8. What type of object has bold, underline, italic, strike, and outline variables?
# --> Runs can be using text attributes like bold, underline, italic, strike etc..
# 9. What is the difference between False, True, and None for the bold variable?
# --> False - means NOT bold feature
#     True: purposely bold feature
#     None: Applies default feature
#
# 10. How do you create a Document object for a new Word document?
# --> Follow this code
# doc = docx.Document()
# doc.save('file_name.docx')
#
# 11. How do you add a paragraph with the text 'Hello, there!' to a Document object stored in a variable named doc?
# --> doc.add_paragraph('Hello, there!')
#
# 12. What integers represent the levels of headings available in Word documents?
# -->
# Level 0 sets to title.
# Level 1 to 9 sets to heading level.
