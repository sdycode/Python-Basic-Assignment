# %% [markdown]
# <a href="https://colab.research.google.com/github/sdycode/Python-Basic-Assignment/blob/main/Assignment_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. What are escape characters, and how do you use them?
# -->
#   To add characters that are not compatible in a string, escape character used.
#   An escape character is a backslash \ followed by the character you want to insert. like
#   \'	Single Quote
#   \\	Backslash
#
# 2. What do the escape characters n and t stand for?
# -->
#   \n	New Line
#   \t	Tab
#
# 3. What is the way to include backslash characters in a string?
# --> Add a backlash before the illegal character want to add
#  like to add "Shubham" in string "my name \"Shubham\""
#
# 4. The string "Howl's Moving Castle" is a correct value. Why isn't the single quote character in the word Howl's not escaped a problem?
# --> As string is enclosed in double quotes, single quote is always ignored.
# Because String started with double quote so demaded @ end also.
#
#
# 5. How do you write a string of newlines if you don't want to use the n character?
# --> Multiline strings can be written by enclosing it in triple quotes like
# ''' my name is
# shubham yeole '''
# In program, by using os.linesep new lines can be added without \n escape character.
# eg. ans = 'name'+ os.linesep + 'surname'
# print(ans) :
# name
# surname
#
#
# 6. What are the values of the given expressions?
# -->
# 'Hello, world!'[1] --> e
# 'Hello, world!'[0:5] --> Hello
# 'Hello, world!'[:5] --> Hello
# 'Hello, world!'[3:] --> lo, world!
#
# 7. What are the values of the following expressions?
# -->
# 'Hello'.upper() --> HELLO
# 'Hello'.upper().isupper() --> True
# 'Hello'.upper().lower() --> hello
#
# 8. What are the values of the following expressions?
# -->
# 'Remember, remember, the fifth of July.'.split()
# --> ['Remember,', 'remember,', 'the', 'fifth', 'of', 'July.']
# '-'.join('There can only one.'.split())
# --> There-can-only-one.
#
# 9. What are the methods for right-justifying, left-justifying, and centering a string?
# -->
# Right justifying : str.rjust(width, fillchar )
#  eg. str = 'shubham'
#       str.rjust(10,'*') --> ***shubham
# Left justifying :
# str.ljust(width, fillchar)
#  str.ljust(10,'*') --> shubham***
#
# centering :
# str.center(width, fillchar)
# str.center(10,'*') --> *shubham**
#
# 10. What is the best way to remove whitespace characters from the start or end?
# -->
# Approach 1: ''.join(str.split())
# Approach 2: replace all space with '' --> str.replace(' ','')
