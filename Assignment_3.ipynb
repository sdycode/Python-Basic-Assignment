# %% [markdown]
# <a href="https://colab.research.google.com/github/sdycode/Python-Basic-Assignment/blob/main/Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Why are functions advantageous to have in your programs?

# %% [markdown]
# --> Functions are used in programs to have features like reusability, clean code, well structured code,  easy to understand. To perform set of complex operations can be achived using Functions

# %% [markdown]
# 2. When does the code in a function run: when it's specified or when it's called?

# %% [markdown]
# --> In case of python, code is run line by line as python is interpreted language. So each line is compiled & then executed. Code is run from top to bottom

# %% [markdown]
# 3. What statement creates a function?

# %% [markdown]
# --> statement to create function is as following :
#    fun functionName() :
#         first statement of function
#         at least 1 statement should be there

# %% [markdown]
# 4. What is the difference between a function and a function call?

# %% [markdown]
# --> function is body where code is written to perform certain operations wher function call is single statement where actual function  is called.

# %% [markdown]
# 5. How many global scopes are there in a Python program? How many local scopes?

# %% [markdown]
# -->
#     -There is only 1 global scope in python program i.e scope inside __main__ program that means outside of any function except main()
#     - There are may local scopes in single program depends on no. of functions in program. Every program has its
#     own local scope

# %% [markdown]
# 6. What happens to variables in a local scope when the function call returns?

# %% [markdown]
# --> Variables in local scope are destroyed as function call return.

# %% [markdown]
# 7. What is the concept of a return value?
# Is it possible to have a return value in an expression?

# %% [markdown]
# --> In case of function, every function gives or return any value in any data form which is used for further process or calculation. If there is no value present to return void is used. return value from function can be used in expression for calculation

# %% [markdown]
# 8. If a function does not have a return statement, what is the return value of a call to that function?

# %% [markdown]
# --> If function doesnt have any return statement, it return void or nothing. In case of python, return value of such function is None.

# %% [markdown]
# 9. How do you make a function variable refer to the global variable?

# %% [markdown]
# --> Global variables can be used in function by writing global keyword.

# %% [markdown]
# 10. What is the data type of None?
# --> Nonetype

# %% [markdown]
# 11. What does the sentence import areallyourpetsnamederic do?
# --> Didnt get any answer

# %% [markdown]
# 13. What can you do to save a programme from crashing if it encounters an error?
# --> We can use try-except clauses to avoid program from crashing

# %% [markdown]
# 14. What is the purpose of the try clause? What is the purpose of the except clause?
# --> If there would be possibility of occuring of error in program, that code is enclosed in try block where if code is crashed, program flow goes to code in except block where exception is handled.
